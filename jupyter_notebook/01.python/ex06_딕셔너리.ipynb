# %% [markdown]
# ## 딕셔너리 사용법

# %%
dic_jiyoung = {"name" : "JY", "age" : 30, "phone" : "010-1234-1234"} #-가 산술연산자로 계산되지 않도록 큰따옴표 안에 적음
dic_jiyoung
# Out:
# {'name': 'JY', 'age': 30, 'phone': '010-1234-1234'}

# %%
dic_jiyoung["age"]
# Out:
# 30

# %%
# 딕셔너리에 새로운 값을 추가할 때
dic_jiyoung["birth"] = "08/10"
dic_jiyoung
# Out:
# {'name': 'JY', 'age': 30, 'phone': '010-1234-1234', 'birth': '08/10'}

# %%
dic_jiyoung.keys()   #하위디렉터로 들어가겠다 하면 온점.
# Out:
# dict_keys(['name', 'age', 'phone', 'birth'])

# %%
dic_jiyoung.values()
# Out:
# dict_values(['JY', 30, '010-1234-1234', '08/10'])

# %%
for key in dic_jiyoung.keys():
    print(key)
# Out:
# name
# age
# phone
# birth

# %%
for value in dic_jiyoung.values():
    print(value)
# Out:
# JY
# 30
# 010-1234-1234
# 08/10

# %%
dic_jiyoung.items()
# Out:
# dict_items([('name', 'JY'), ('age', 30), ('phone', '010-1234-1234'), ('birth', '08/10')])

# %% [markdown]
# #del dic_jiyoung[]       []안에 내용 삭제할땐 del을 쓰면 된다.

# %% [markdown]
# dic_jiyoung.clear()      내용 전부다 삭제할땐 clear을 쓰면 된다.

# %% [markdown]
# ![image.png](attachment:7c9eb4fa-c535-48fc-be74-4f8c2ceff244.png)

# %%
score_dic = {'홍길동' : {'수학' : 99, '영어' : 80, '국어' : 75},
             '김미정' : {'영어' : 67, '국어' : 87, '수학' : 55},
             '정수진' : {'수학' : 67, '국어' : 41, '영어' : 23 }}

score_dic
# Out:
# {'홍길동': {'수학': 99, '영어': 80, '국어': 75},
#  '김미정': {'영어': 67, '국어': 87, '수학': 55},
#  '정수진': {'수학': 67, '국어': 41, '영어': 23}}

# %%
math = score_dic['홍길동']['수학'] + score_dic['김미정']['수학'] + score_dic['정수진']['수학'] 
korea = score_dic['홍길동']['국어'] + score_dic['김미정']['국어'] + score_dic['정수진']['국어'] 
eng = score_dic['홍길동']['영어'] + score_dic['김미정']['영어'] + score_dic['정수진']['영어']

# %%
dic = {}
dic = {'수학' : math,
       '국어' : korea,
       '영어' : eng}

print(dic)
# Out:
# {'수학': 221, '국어': 203, '영어': 170}
